# %% [markdown]
# <a href="https://colab.research.google.com/github/Edenshmuel/PapaJohns_Data_Science_Project/blob/main/Cleaned_Data_Sales_Channel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
cleaned_data = pd.read_csv('/content/drive/MyDrive/Final_Project_PapaJohns/cleaned_data_Sales_channels.csv')

# %%
df = cleaned_data.copy()

# %%
df.sample(3)
# Out:
#               Date  Year  Month  Day  Day_Name  Is_Weekend  סכום  כמות  \
# 199523  2024-10-16  2024     10   16         4           0  0.00     1
# 198001  2024-10-11  2024     10   11         6           1  4.95     1
# 32930   2022-03-30  2022      3   30         4           0  4.95     1
#
#         is_christian_holiday  is_jewish_holiday  ...  Day_Name_cos  Month_sin  \
# 199523                 False              False  ...     -0.900969  -0.866025
# 198001                 False              False  ...      0.623490  -0.866025
# 32930                  False              False  ...     -0.900969   1.000000
#
#            Month_cos  avg_quantity_all_time  std_quantity_all_time  \
# 199523  5.000000e-01               1.009646               0.097898
# 198001  5.000000e-01               1.374919               0.563636
# 32930   6.123234e-17               1.308601               0.649768
#
#         num_days_sold  popularity_score  encoded_jewish_holiday  \
# ...

# %%
channels = ['Wolt', '10bis', 'PapaJohns App', 'Cibus', 'Telephone', 'Store']
probabilities = [0.37, 0.27, 0.18, 0.10, 0.05, 0.03]

# %%
np.random.seed(42)

# %%
df['sales_channel'] = np.random.choice(channels, size=len(df), p=probabilities)

# %%
df.sample(3)
# Out:
#               Date  Year  Month  Day  Day_Name  Is_Weekend  סכום  כמות  \
# 57618   2023-03-16  2023      3   16         5           0   0.0     1
# 159977  2024-06-25  2024      6   25         3           0   5.8     2
# 45456   2023-02-10  2023      2   10         6           1  25.0     1
#
#         is_christian_holiday  is_jewish_holiday  ...     Month_sin  \
# 57618                  False              False  ...  1.000000e+00
# 159977                 False              False  ...  1.224647e-16
# 45456                  False              False  ...  8.660254e-01
#
#            Month_cos  avg_quantity_all_time  std_quantity_all_time  \
# 57618   6.123234e-17               1.065724               0.268573
# 159977 -1.000000e+00               1.308601               0.649768
# 45456   5.000000e-01               1.108909               0.366173
#
#         num_days_sold  popularity_score  encoded_jewish_holiday  \
# 57618             491          1.065724                       0
# ...

# %%
channel_counts = df['sales_channel'].value_counts()
channel_percentages = df['sales_channel'].value_counts(normalize=True) * 100

distribution_df = pd.DataFrame({
    'Count': channel_counts,
    'Percentage': channel_percentages.round(2)})

# %%
print(distribution_df)
# Out:
#                Count  Percentage
# sales_channel
# Wolt           85456       36.98
# 10bis          62185       26.91
# PapaJohns App  41732       18.06
# Cibus          23262       10.07
# Telephone      11543        5.00
# Store           6903        2.99

# %%
# df.to_csv('/content/drive/MyDrive/Final_Project_PapaJohns/cleaned_data_with_sales_channel.csv', index=False)
